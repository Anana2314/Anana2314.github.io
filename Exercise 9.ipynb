# %%
import pandas as pd

df = pd.read_csv("/Users/anamontanez/Documents/Anana2314.github.io/LAB9.csv")

print(df.head(10))
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2023-01-01T00:32:10.000  2023-01-01T00:40:36.000
# 1         2  2023-01-01T00:55:08.000  2023-01-01T01:01:27.000
# 2         2  2023-01-01T00:25:04.000  2023-01-01T00:37:49.000
# 3         1  2023-01-01T00:03:48.000  2023-01-01T00:13:25.000
# 4         2  2023-01-01T00:10:29.000  2023-01-01T00:21:19.000
# 5         2  2023-01-01T00:50:34.000  2023-01-01T01:02:52.000
# 6         2  2023-01-01T00:09:22.000  2023-01-01T00:19:49.000
# 7         2  2023-01-01T00:27:12.000  2023-01-01T00:49:56.000
# 8         2  2023-01-01T00:21:44.000  2023-01-01T00:36:40.000
# 9         2  2023-01-01T00:39:42.000  2023-01-01T00:50:36.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0              1.0           0.97         1.0                  N
# 1              1.0           1.10         1.0                  N
# 2              1.0           2.51         1.0                  N
# ...

# %%
# Print all trip distances
print("\nTrip distances:")
print(df['trip_distance'])
# Out:
# Trip distances:
# 0       0.97
# 1       1.10
# 2       2.51
# 3       1.90
# 4       1.43
#        ...
# 995     2.12
# 996     0.00
# 997    17.80
# 998     1.20
# 999     0.90
# Name: trip_distance, Length: 1000, dtype: float64

# %%
print("\nSummary statistics for trip distance:")
print(df['trip_distance'].describe())
# Out:
# Summary statistics for trip distance:
# count    1000.000000
# mean        2.961940
# std         3.233793
# min         0.000000
# 25%         1.147500
# 50%         1.930000
# 75%         3.400000
# max        30.150000
# Name: trip_distance, dtype: float64

# %%
average_distance = df['trip_distance'].mean()
print("Average ride distance:", average_distance)
# Out:
# Average ride distance: 2.9619400000000002

# %%
# Fastest & simplest way to calculated in pandas
percent_credit = df['payment_type'].eq(1).mean() * 100
print(f"{percent_credit:.2f}%")
# Out:
# 77.20%

# %%
sample_df = df.sample(frac=0.2, random_state=42)
sample_df.to_csv("sample_trips.csv", index=False)

# %%
# Write a paragraph or two of reflection on Lecture 18 and this Lab, 
# specifically around the strict use of generative AI.

#What worked well?

#What didn’t work well?

#Did this change how you’re thinking about generative AI?

#I personally used AI for assisting me in tasks at work or with coding, so its not something
# has surprised me. It worked really well after I have more precise information, when I can't 
# find the way I just copy the output to the chat and try to rephrase. No, the wrong 
# information didn't change how I think about AI just reminds me to be critical and check 
# what chatgpt or any other AI is replying to me.
